# %%
import backtester_delayed
import matplotlib.pyplot as plt
# %matplotlib notebook

def runTest(startDate, endDate, currencies=None):
    balancer, date = backtester_delayed.doBacktest(startDate, endDate, currencies)
    
    plt.plot(balancer.worth, color='blue')
    plt.plot(balancer.buyandholdworth, color='red')
    plt.show()

# %%
# %matplotlib notebook
runTest('2018-06-01', '2018-10-30')
# Out:
# /home/eric/workspace/balancer/balancer/backtester_delayed.py:5: FutureWarning:
# Panel is deprecated and will be removed in a future version.
# The recommended way to represent these types of 3-dimensional data are with a MultiIndex on a DataFrame, via the Panel.to_frame() method
# Alternatively, you can use the xarray package http://xarray.pydata.org/en/stable/.
# Pandas provides a `.to_xarray()` method to help automate this conversion.
#
#   records = data.getLinearData()
# /home/eric/.local/share/virtualenvs/balancer-SWjXAcCD/lib/python3.7/site-packages/pandas/core/generic.py:5382: FutureWarning:
# Panel is deprecated and will be removed in a future version.
# The recommended way to represent these types of 3-dimensional data are with a MultiIndex on a DataFrame, via the Panel.to_frame() method
# Alternatively, you can use the xarray package http://xarray.pydata.org/en/stable/.
# Pandas provides a `.to_xarray()` method to help automate this conversion.
#
#   from_dict(result).__finalize__(self)
# /home/eric/.local/share/virtualenvs/balancer-SWjXAcCD/lib/python3.7/site-packages/pandas/core/panel.py:1276: FutureWarning:
# Panel is deprecated and will be removed in a future version.
# The recommended way to represent these types of 3-dimensional data are with a MultiIndex on a DataFrame, via the Panel.to_frame() method
# Alternatively, you can use the xarray package http://xarray.pydata.org/en/stable/.
# Pandas provides a `.to_xarray()` method to help automate this conversion.
#
#   downcast=downcast, **kwargs)
# /home/eric/workspace/balancer/balancer/backtester_delayed.py:15: FutureWarning:
# Panel is deprecated and will be removed in a future version.
# The recommended way to represent these types of 3-dimensional data are with a MultiIndex on a DataFrame, via the Panel.to_frame() method
# Alternatively, you can use the xarray package http://xarray.pydata.org/en/stable/.
# Pandas provides a `.to_xarray()` method to help automate this conversion.
#
#   records = records.swapaxes(0, 1)
# /home/eric/.local/share/virtualenvs/balancer-SWjXAcCD/lib/python3.7/site-packages/pandas/core/indexing.py:150: FutureWarning:
# Panel is deprecated and will be removed in a future version.
# The recommended way to represent these types of 3-dimensional data are with a MultiIndex on a DataFrame, via the Panel.to_frame() method
# Alternatively, you can use the xarray package http://xarray.pydata.org/en/stable/.
# Pandas provides a `.to_xarray()` method to help automate this conversion.
#
#   return self.obj._slice(obj, axis=axis, kind=kind)
# <img src="data:image/png;base64,..." width="640">

# %%
# %matplotlib notebook
runTest('2018-06-01', '2018-10-30', ['btc', 'xmr', 'ltc', 'xrp', 'xlm', 'eth', 'dash', 'neo'])
# Out:
# /home/eric/workspace/balancer/balancer/backtester_delayed.py:5: FutureWarning:
# Panel is deprecated and will be removed in a future version.
# The recommended way to represent these types of 3-dimensional data are with a MultiIndex on a DataFrame, via the Panel.to_frame() method
# Alternatively, you can use the xarray package http://xarray.pydata.org/en/stable/.
# Pandas provides a `.to_xarray()` method to help automate this conversion.
#
#   records = data.getLinearData()
# /home/eric/.local/share/virtualenvs/balancer-SWjXAcCD/lib/python3.7/site-packages/pandas/core/generic.py:5382: FutureWarning:
# Panel is deprecated and will be removed in a future version.
# The recommended way to represent these types of 3-dimensional data are with a MultiIndex on a DataFrame, via the Panel.to_frame() method
# Alternatively, you can use the xarray package http://xarray.pydata.org/en/stable/.
# Pandas provides a `.to_xarray()` method to help automate this conversion.
#
#   from_dict(result).__finalize__(self)
# /home/eric/.local/share/virtualenvs/balancer-SWjXAcCD/lib/python3.7/site-packages/pandas/core/panel.py:1276: FutureWarning:
# Panel is deprecated and will be removed in a future version.
# The recommended way to represent these types of 3-dimensional data are with a MultiIndex on a DataFrame, via the Panel.to_frame() method
# Alternatively, you can use the xarray package http://xarray.pydata.org/en/stable/.
# Pandas provides a `.to_xarray()` method to help automate this conversion.
#
#   downcast=downcast, **kwargs)
# /home/eric/workspace/balancer/balancer/backtester_delayed.py:15: FutureWarning:
# Panel is deprecated and will be removed in a future version.
# The recommended way to represent these types of 3-dimensional data are with a MultiIndex on a DataFrame, via the Panel.to_frame() method
# Alternatively, you can use the xarray package http://xarray.pydata.org/en/stable/.
# Pandas provides a `.to_xarray()` method to help automate this conversion.
#
#   records = records.swapaxes(0, 1)
# /home/eric/.local/share/virtualenvs/balancer-SWjXAcCD/lib/python3.7/site-packages/pandas/core/indexing.py:150: FutureWarning:
# Panel is deprecated and will be removed in a future version.
# The recommended way to represent these types of 3-dimensional data are with a MultiIndex on a DataFrame, via the Panel.to_frame() method
# Alternatively, you can use the xarray package http://xarray.pydata.org/en/stable/.
# Pandas provides a `.to_xarray()` method to help automate this conversion.
#
#   return self.obj._slice(obj, axis=axis, kind=kind)
# <img src="data:image/png;base64,..." width="640">

# %%
# %matplotlib notebook
runTest('2018-06-01', '2018-10-30', ['btc', 'ltc', 'eth'])
# Out:
# /home/eric/workspace/balancer/balancer/backtester_delayed.py:5: FutureWarning:
# Panel is deprecated and will be removed in a future version.
# The recommended way to represent these types of 3-dimensional data are with a MultiIndex on a DataFrame, via the Panel.to_frame() method
# Alternatively, you can use the xarray package http://xarray.pydata.org/en/stable/.
# Pandas provides a `.to_xarray()` method to help automate this conversion.
#
#   records = data.getLinearData()
# /home/eric/.local/share/virtualenvs/balancer-SWjXAcCD/lib/python3.7/site-packages/pandas/core/generic.py:5382: FutureWarning:
# Panel is deprecated and will be removed in a future version.
# The recommended way to represent these types of 3-dimensional data are with a MultiIndex on a DataFrame, via the Panel.to_frame() method
# Alternatively, you can use the xarray package http://xarray.pydata.org/en/stable/.
# Pandas provides a `.to_xarray()` method to help automate this conversion.
#
#   from_dict(result).__finalize__(self)
# /home/eric/.local/share/virtualenvs/balancer-SWjXAcCD/lib/python3.7/site-packages/pandas/core/panel.py:1276: FutureWarning:
# Panel is deprecated and will be removed in a future version.
# The recommended way to represent these types of 3-dimensional data are with a MultiIndex on a DataFrame, via the Panel.to_frame() method
# Alternatively, you can use the xarray package http://xarray.pydata.org/en/stable/.
# Pandas provides a `.to_xarray()` method to help automate this conversion.
#
#   downcast=downcast, **kwargs)
# /home/eric/workspace/balancer/balancer/backtester_delayed.py:15: FutureWarning:
# Panel is deprecated and will be removed in a future version.
# The recommended way to represent these types of 3-dimensional data are with a MultiIndex on a DataFrame, via the Panel.to_frame() method
# Alternatively, you can use the xarray package http://xarray.pydata.org/en/stable/.
# Pandas provides a `.to_xarray()` method to help automate this conversion.
#
#   records = records.swapaxes(0, 1)
# /home/eric/.local/share/virtualenvs/balancer-SWjXAcCD/lib/python3.7/site-packages/pandas/core/indexing.py:150: FutureWarning:
# Panel is deprecated and will be removed in a future version.
# The recommended way to represent these types of 3-dimensional data are with a MultiIndex on a DataFrame, via the Panel.to_frame() method
# Alternatively, you can use the xarray package http://xarray.pydata.org/en/stable/.
# Pandas provides a `.to_xarray()` method to help automate this conversion.
#
#   return self.obj._slice(obj, axis=axis, kind=kind)
# <img src="data:image/png;base64,..." width="640">

# %%
# %matplotlib notebook
runTest('2017-08-01', '2017-12-31')
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
# %matplotlib notebook
runTest('2017-06-01', '2017-09-01')
# Out:
# <img src="data:image/png;base64,..." width="640">
