# %%
import backtester_delayed
import matplotlib.pyplot as plt
# %matplotlib notebook

def runTest(startDate, endDate, currencies=None):
    balancer, date = backtester_delayed.doBacktest(startDate, endDate, currencies)
    
    plt.plot(balancer.worth, color='blue')
    plt.plot(balancer.buyandholdworth, color='red')
    plt.show()

# %%
# %matplotlib notebook
runTest('2017-01-01', '2017-12-31')
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
# %matplotlib notebook
runTest('2017-01-01', '2018-01-02', ['btc', 'xmr', 'ltc', 'xrp', 'xlm', 'eth', 'dash', 'neo'])
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
# %matplotlib notebook
runTest('2017-01-01', '2017-12-31', ['btc', 'ltc', 'eth'])
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
# %matplotlib notebook
runTest('2017-08-01', '2017-12-31')
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
# %matplotlib notebook
runTest('2017-06-01', '2017-09-01')
# Out:
# <img src="data:image/png;base64,..." width="640">
